# %% [markdown]
# # Tinyflux: Example with fictious bank transactions

# %%
import csv
from tinyflux import TinyFlux, Point, FieldQuery, TagQuery, TimeQuery
from datetime import datetime, timezone, timedelta

# %% [markdown]
# ## Initialize the TinyFlux database

# %%
db = TinyFlux("synthetic_temperature_readings.db")

# %% [markdown]
# ## Writing a CSV file into Tinyflux

# %%
# Read CSV and insert data into TinyFlux
with open("example_data/synthetic_temperature_readings.csv", mode="r") as file:
    reader = csv.DictReader(file)
    for row in reader:
        point = Point(
            time=datetime.strptime(row["time"], "%Y-%m-%d %H:%M:%S"),
            measurement="transactions",
            fields={"temperature": float(row["temperature"])},  # Only numeric fields
            tags={
                "status": row["status"],
                "sensor_id": row["sensor_id"],
            }
        )
        db.insert(point)

# %% [markdown]
# ## Writing manually into Tinyflux

# %%
# Create manual records
p1 = Point(
    time=datetime(2024, 1, 1, 12, 0, tzinfo=timezone.utc),
    tags={"sensor_id": "98","status": "online"},
    fields={"temperature": 4.444444}
)

p2 = Point(
    time=datetime(2024, 1, 1, 12, 0, tzinfo=timezone.utc),
    tags={"sensor_id": "98","status": "online"},
    fields={"temperature": 4.444445}
)

p3 = Point(
    time=datetime(2024, 7, 31, 12, 0, tzinfo=timezone.utc),
    tags={"sensor_id": "98","status": "online"},
    fields={"temperature": 31.798798}
)

p4 = Point(
    time=datetime(2024, 7, 31, 12, 0, tzinfo=timezone.utc),
    tags={"sensor_id": "98","status": "online"},
    fields={"temperature": 31.798799}
)

p5 = Point(
    time=datetime(2024, 7, 31, 12, 0, tzinfo=timezone.utc),
    tags={"sensor_id": "98","status": "online"},
    fields={"temperature": 31.798800}
)

# Insert into the DB.
db.insert_multiple([p1, p2, p3, p4, p5])
# Out:
# 5

# %% [markdown]
# ## Querying by Time

# %%
# Search for a time value
Time = TimeQuery()
time_start = Time >= datetime(2024, 7, 1, tzinfo=timezone.utc)
time_end = Time < datetime(2024, 8, 1, tzinfo=timezone.utc)
time_count = db.count(time_start & time_end)
print("\nTime Query Count:")
print(time_count)
# Out:
# Time Query Count:
# 3

# %% [markdown]
# ## Querying by Field

# %%
# Search for a field value
Field = FieldQuery()
field_results = db.select("fields.temperature", Field.temperature > 31.7)
print("\nField Query Results:")
for result in field_results:
    print(result)
# Out:
# Field Query Results:
# 36.68459118799373
# 32.54087589180731
# 32.11570176490908
# 39.86277673841972
# 34.83051314870104
# 35.86978065427658
# 38.753358147257124
# 31.92912793513124
# 38.39970332521171
# 36.60071711284671
# 32.536373000822735
# 36.64690335499773
# 39.54647382286953
# 36.32247117948556
# 35.3933065231258
# 34.983372264608654
# 33.93145576867191
# 39.88463079619216
# 37.95373972820139
# 35.59262044214824
# 35.93752611303732
# 32.021981599021146
# 35.53430991278565
# 31.8745394501246
# 33.17590703064785
# 36.148011589924245
# 35.92273624696506
# 35.63747314395644
# 38.77706578413781
# 33.031600894536695
# 31.828240664616644
# 34.871520490944214
# 38.94657178079806
# 31.989442972828527
# 33.34968800057617
# 34.37302412567515
# 39.43643909777214
# 38.13246592774373
# 37.220486278863675
# 32.40640477334418
# 33.82220379376469
# 35.531200177015194
# 33.05340099873608
# 38.727363259943495
# 39.26836561208673
# 35.02861506181928
# 37.931358865661025
# 31.85394953515147
# 35.7756838645957
# 37.465339852888285
# 37.704346826981656
# 32.07648301550217
# 32.32039246572786
# 37.76181563617395
# 38.38496941035432
# 38.104939288205884
# 37.908539650196516
# 39.02884000899941
# 35.168190631801245
# 39.96767497829174
# 34.24991782616405
# 33.83326889312247
# 39.51706566708886
# 36.62949547126264
# 32.64109108459507
# 35.516955102876715
# 37.82078487797125
# 39.11652575400408
# 34.20994890657515
# 35.18619835876353
# 39.459245490667946
# 31.891286764162274
# 37.86351314916628
# 39.81678879033621
# 34.871807402310196
# 34.74607206139199
# 33.00634082089619
# 32.609676667350385
# 36.5794744159495
# 38.10609862960249
# 34.72399654840337
# 39.57376675725241
# 34.14531345687306
# 35.325685972229
# 33.224644015367424
# 33.40804020257735
# 36.50451752548693
# 34.08185663851751
# 38.06576440924537
# 33.95357401140658
# 35.43506546346839
# 32.00607513706094
# 37.3648944128169
# 32.62073295993238
# 39.50741863753235
# 37.21518174789149
# 32.7104887230783
# 31.997358233623594
# 33.40271612661464
# 38.1618326720066
# 35.47622554739092
# 32.86800460462493
# 38.22602361351043
# 33.40614067452655
# 35.591801747995554
# 38.375563180688886
# 39.2175703701452
# 38.73499259353449
# 37.63243190193585
# 35.390932649232006
# 37.06187521161932
# 34.12667429098
# 38.87331931573929
# 37.577498717766346
# 34.81106513425191
# 36.760090764972986
# 37.367523131551934
# 33.59163894865606
# 32.02262031384667
# 38.03902757434885
# 32.31226460095247
# 39.606665817033615
# 31.799903189060473
# 32.89931269613529
# 34.18548348303763
# 37.429167742571686
# 33.210808883708445
# 39.33464901785808
# 38.65488740351732
# 36.99098959634209
# 38.16734164101995
# 38.93156437002652
# 33.23044179775184
# 35.93388984967521
# 37.04376781690324
# 33.32193337638227
# 39.666846867931426
# 36.28374154403559
# 35.06878247942222
# 33.89455795206638
# 33.44503127702855
# 37.573927983299555
# 32.35836806862871
# 35.711825797573496
# 34.83571449200612
# 37.73300150166537
# 36.48029387109946
# 38.836261933128945
# 32.97078966402946
# 35.887624458568865
# 35.29455523938802
# 32.558713042638544
# 33.46298123255263
# 35.27623961648369
# 39.77402453521285
# 38.08328679774066
# 39.061818717215196
# 38.708231431400776
# 33.23430960167701
# 31.798798
# 31.798799
# 31.7988

# %% [markdown]
# ## Querying by Tag

# %%
# Search for a tag value
Tag = TagQuery()
tag_results = db.search(Tag.status == 'online')
print("Tag Query Results:")
for result in tag_results:
    print(result)
# Out:
# Tag Query Results:
# Point(time=2024-01-01T12:00:00+00:00, measurement=_default, tags=sensor_id:98; status:online, fields=temperature:4.444444)
# Point(time=2024-01-01T12:00:00+00:00, measurement=_default, tags=sensor_id:98; status:online, fields=temperature:4.444444)
# Point(time=2024-01-01T12:00:00+00:00, measurement=_default, tags=sensor_id:98; status:online, fields=temperature:4.444444)
# Point(time=2024-01-01T12:00:00+00:00, measurement=_default, tags=sensor_id:98; status:online, fields=temperature:4.444444)
# Point(time=2024-01-01T12:00:00+00:00, measurement=_default, tags=sensor_id:98; status:online, fields=temperature:4.444444)
# Point(time=2024-01-01T12:00:00+00:00, measurement=_default, tags=sensor_id:98; status:online, fields=temperature:4.444445)
# Point(time=2024-01-01T12:00:00+00:00, measurement=_default, tags=sensor_id:98; status:online, fields=temperature:4.444444)
# Point(time=2024-01-01T12:00:00+00:00, measurement=_default, tags=sensor_id:98; status:online, fields=temperature:4.444445)
# Point(time=2024-01-01T12:00:00+00:00, measurement=_default, tags=sensor_id:98; status:online, fields=temperature:4.444444)
# Point(time=2024-01-01T12:00:00+00:00, measurement=_default, tags=sensor_id:98; status:online, fields=temperature:4.444445)
# Point(time=2024-01-02T12:00:00+00:00, measurement=_default, tags=sensor_id:98; status:online, fields=temperature:4.444445)
# Point(time=2024-01-02T12:00:00+00:00, measurement=_default, tags=sensor_id:98; status:online, fields=temperature:4.444445)
# Point(time=2024-01-02T12:00:00+00:00, measurement=_default, tags=sensor_id:98; status:online, fields=temperature:4.444445)
# Point(time=2024-01-02T12:00:00+00:00, measurement=_default, tags=sensor_id:98; status:online, fields=temperature:4.444445)
# Point(time=2024-07-31T12:00:00+00:00, measurement=_default, tags=sensor_id:98; status:online, fields=temperature:31.798798)
# Point(time=2024-07-31T12:00:00+00:00, measurement=_default, tags=sensor_id:98; status:online, fields=temperature:31.798799)
# Point(time=2024-07-31T12:00:00+00:00, measurement=_default, tags=sensor_id:98; status:online, fields=temperature:31.7988)
